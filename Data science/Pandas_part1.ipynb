# %% [markdown]
# ## Mastering pandas: Load, Clean, Analyze Engineering Student Journey Data

# %% [markdown]
# ## 🧠 1. Why This Dataset
# Real-world data from students
#
# Mix of numerical, categorical, and missing values
#
# Great for demonstrating a full pandas workflow

# %% [markdown]
# ## 📦 2. Setup & Loading Data

# %% [markdown]
# Simple way to read the dataset, if it is available in the same path of the script.

# %%
import pandas as pd

df = pd.read_csv('students.csv')

# %% [markdown]
# If the file is in another path then we need to pass the entire repository of the input file

# %%
df=pd.read_csv("students.csv")
df
# Out:
#                                 Student ID                 Name   Age  Gender  \
# 0     b37412a3-fa5c-40ca-b087-7109a47482d7                 Amit  21.0    Male
# 1     65001423-faeb-4d19-a550-8ea26133a34d         Tina Ballard  19.0    Male
# 2     228aaf1d-8710-4c8d-bfec-001b0df01f34                Meena  19.0  Female
# 3     1aa67474-e200-4157-ad54-c95aaa4d52a8  Christopher Morales  23.0    Male
# 4     5122db4a-14c8-44d7-b2f4-e869f69d3dd7            Siddharth  20.0    Male
# ...                                    ...                  ...   ...     ...
# 1995  27d7e5aa-dc11-40a7-9aff-586f00f8d55b                 Anil  19.0    Male
# 1996  74f43a77-70a1-4e4c-a0c2-460d939618c9                Ramya  23.0  Female
# 1997  88a613b4-a3b8-4f92-a3c9-0c6a86017633    Gregory Fernandez  18.0    Male
# 1998  248c7b65-0c61-4277-9e95-44857b54d1a9               Vikram  22.0    Male
# 1999  840d718e-de7b-4218-95bd-11db983c3cbd            Siddharth  20.0    Male
#
# ...

# %% [markdown]
# To find the shape of our input data

# %%
df.shape
# Out:
# (2000, 24)

# %% [markdown]
# (2000, 24) here first index is rows and another one is columns

# %% [markdown]
# If we need to print our loaded data frame we just call the variable name and it will print first and last 5 rows

# %%
df
# Out:
#                                 Student ID                 Name   Age  Gender  \
# 0     b37412a3-fa5c-40ca-b087-7109a47482d7                 Amit  21.0    Male
# 1     65001423-faeb-4d19-a550-8ea26133a34d         Tina Ballard  19.0    Male
# 2     228aaf1d-8710-4c8d-bfec-001b0df01f34                Meena  19.0  Female
# 3     1aa67474-e200-4157-ad54-c95aaa4d52a8  Christopher Morales  23.0    Male
# 4     5122db4a-14c8-44d7-b2f4-e869f69d3dd7            Siddharth  20.0    Male
# ...                                    ...                  ...   ...     ...
# 1995  27d7e5aa-dc11-40a7-9aff-586f00f8d55b                 Anil  19.0    Male
# 1996  74f43a77-70a1-4e4c-a0c2-460d939618c9                Ramya  23.0  Female
# 1997  88a613b4-a3b8-4f92-a3c9-0c6a86017633    Gregory Fernandez  18.0    Male
# 1998  248c7b65-0c61-4277-9e95-44857b54d1a9               Vikram  22.0    Male
# 1999  840d718e-de7b-4218-95bd-11db983c3cbd            Siddharth  20.0    Male
#
# ...

# %% [markdown]
# ## 🔍 3. Basic EDA & Exploration
# 1. df.head(), df.tail()
#
# 2. df.info() – check columns and types
#
# 3. df.describe() – get a statistical summary

# %% [markdown]
# We can also print first 5 rows from our dataset using **head()**

# %%
df.head()
# Out:
#                              Student ID                 Name   Age  Gender  \
# 0  b37412a3-fa5c-40ca-b087-7109a47482d7                 Amit  21.0    Male
# 1  65001423-faeb-4d19-a550-8ea26133a34d         Tina Ballard  19.0    Male
# 2  228aaf1d-8710-4c8d-bfec-001b0df01f34                Meena  19.0  Female
# 3  1aa67474-e200-4157-ad54-c95aaa4d52a8  Christopher Morales  23.0    Male
# 4  5122db4a-14c8-44d7-b2f4-e869f69d3dd7            Siddharth  20.0    Male
#
#   Branch  Average GPA  Backlogs  Attendance (%)  \
# 0   MECH         6.99       0.0           70.45
# 1    ECE         6.46       0.0           65.45
# 2  CIVIL         7.08       0.0           84.79
# 3    ECE         6.92       2.0           62.26
# 4    EEE         7.09       0.0           97.12
#
#                                 Clubs                               Skills  \
# 0          Literary Society, Robotics  C++, Machine Learning, Python, Java
# ...

# %% [markdown]
# We can also print last 5 rows from our dataset using **tail()**

# %%
df.tail()
# Out:
#                                 Student ID               Name   Age  Gender  \
# 1995  27d7e5aa-dc11-40a7-9aff-586f00f8d55b               Anil  19.0    Male
# 1996  74f43a77-70a1-4e4c-a0c2-460d939618c9              Ramya  23.0  Female
# 1997  88a613b4-a3b8-4f92-a3c9-0c6a86017633  Gregory Fernandez  18.0    Male
# 1998  248c7b65-0c61-4277-9e95-44857b54d1a9             Vikram  22.0    Male
# 1999  840d718e-de7b-4218-95bd-11db983c3cbd          Siddharth  20.0    Male
#
#      Branch  Average GPA  Backlogs  Attendance (%)  \
# 1995     IT         7.69       2.0           92.45
# 1996  CIVIL         7.25       0.0           96.35
# 1997    EEE         6.92       0.0           75.32
# 1998    CSE         7.09       0.0           94.20
# 1999     IT         6.52       0.0           60.28
#
#                                                   Clubs  \
# 1995     Cultural Club, Robotics, Entrepreneurship Cell
# 1996            Entrepreneurship Cell, Literary Society
# ...

# %%
df.columns
# Out:
# Index(['Student ID', 'Name', 'Age', 'Gender', 'Branch', 'Average GPA',
#        'Backlogs', 'Attendance (%)', 'Clubs', 'Skills', 'Internship Done',
#        'Internship Domain', 'Placement Status', 'Placement Domain',
#        'CTC (LPA)', 'Alumni Path', 'Sem1 GPA', 'Sem2 GPA', 'Sem3 GPA',
#        'Sem4 GPA', 'Sem5 GPA', 'Sem6 GPA', 'Sem7 GPA', 'Sem8 GPA'],
#       dtype='object')

# %%
df['Salary']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df['Salary']
#
# ...

# %%
df['Salary']=df['CTC (LPA)'].apply(lambda x: x*100000 if pd.notna(x) else  x)

# %%
df[df['Salary']>1000000]
# Out:
#                                 Student ID            Name   Age  Gender  \
# 10    e87d1c78-e7c4-41c7-8049-7b717d106c60  Anna Henderson  23.0  Female
# 12    1750bd26-bcfc-4af5-9881-a1f0fbbb523a           Pooja  23.0  Female
# 14    f0cd7f05-ea87-455e-a382-95d31e0ef546  Lucas Robinson  20.0  Female
# 15    c24369e7-2387-4af6-94c3-a832b231c60b      Joan Smith  23.0    Male
# 17    7a8d03aa-782a-45e0-88ca-765192f5df7b   Cody Williams  21.0  Female
# ...                                    ...             ...   ...     ...
# 1978  2d8ba019-500f-4a92-ad48-f0e37e0710d3          Vikram  22.0    Male
# 1986  dc9bb95a-8d82-4588-ba3f-476287e09a4b            Amit  19.0    Male
# 1989  0b705933-4cde-4b6b-9132-567c51a40d2a  Ashley Sweeney  20.0  Female
# 1990  5e781fd7-94e0-43ba-a9f9-48b24e6384bb  Joseph Coleman  22.0    Male
# 1994  e0df9d28-94ae-404e-a5ca-3a2257b0e189           Sonal  23.0  Female
#
#      Branch  Average GPA  Backlogs  Attendance (%)  \
# ...

# %%
df[(df['Salary']>1000000)|(df['Gender']=="Male")]
# Out:
#                                 Student ID                 Name   Age  Gender  \
# 0     b37412a3-fa5c-40ca-b087-7109a47482d7                 Amit  21.0    Male
# 1     65001423-faeb-4d19-a550-8ea26133a34d         Tina Ballard  19.0    Male
# 3     1aa67474-e200-4157-ad54-c95aaa4d52a8  Christopher Morales  23.0    Male
# 4     5122db4a-14c8-44d7-b2f4-e869f69d3dd7            Siddharth  20.0    Male
# 5     28dd6ff3-6391-4421-ba38-3c3164b96252            Siddharth  19.0    Male
# ...                                    ...                  ...   ...     ...
# 1994  e0df9d28-94ae-404e-a5ca-3a2257b0e189                Sonal  23.0  Female
# 1995  27d7e5aa-dc11-40a7-9aff-586f00f8d55b                 Anil  19.0    Male
# 1997  88a613b4-a3b8-4f92-a3c9-0c6a86017633    Gregory Fernandez  18.0    Male
# 1998  248c7b65-0c61-4277-9e95-44857b54d1a9               Vikram  22.0    Male
# 1999  840d718e-de7b-4218-95bd-11db983c3cbd            Siddharth  20.0    Male
#
# ...

# %%
df[(df['Salary']>1000000)&(df['Gender']=="Male")]
# Out:
#                                 Student ID            Name   Age Gender  \
# 15    c24369e7-2387-4af6-94c3-a832b231c60b      Joan Smith  23.0   Male
# 44    69bcdf4c-f0f4-4cf5-ae95-1c33ed5d4e6b          Vikram  19.0   Male
# 55    dfd410a5-920d-434b-bd1d-6eabacc0b7b9           Rahul  19.0   Male
# 69    713b7bd8-ecea-4668-8c31-a7deab2ec2d0          Rakesh  22.0   Male
# 75    c2baf0e0-2179-43f0-a612-4ab4f9b21e6e   Justin Flores  18.0   Male
# ...                                    ...             ...   ...    ...
# 1940  b89a9728-c675-41eb-b950-75ead36ed18b            Amit  23.0   Male
# 1975  4825d876-bf57-4dbe-a8d4-b9cb3b2bb0d0       Siddharth  20.0   Male
# 1978  2d8ba019-500f-4a92-ad48-f0e37e0710d3          Vikram  22.0   Male
# 1986  dc9bb95a-8d82-4588-ba3f-476287e09a4b            Amit  19.0   Male
# 1990  5e781fd7-94e0-43ba-a9f9-48b24e6384bb  Joseph Coleman  22.0   Male
#
#      Branch  Average GPA  Backlogs  Attendance (%)  \
# ...

# %%
df[(df['Salary']>1000000)&(df['Gender']=="Female")]
# Out:
#                                 Student ID              Name   Age  Gender  \
# 10    e87d1c78-e7c4-41c7-8049-7b717d106c60    Anna Henderson  23.0  Female
# 12    1750bd26-bcfc-4af5-9881-a1f0fbbb523a             Pooja  23.0  Female
# 14    f0cd7f05-ea87-455e-a382-95d31e0ef546    Lucas Robinson  20.0  Female
# 17    7a8d03aa-782a-45e0-88ca-765192f5df7b     Cody Williams  21.0  Female
# 19    05a321d4-578e-468a-a1bf-4038a4de8d28             Pooja  22.0  Female
# ...                                    ...               ...   ...     ...
# 1934  f6d22a7b-aec7-4a82-948b-4376602a4e57   Kimberly Valdez  18.0  Female
# 1937  e4ad5e9b-fedd-42d9-a26c-bc6a7fe5a4b6          Kelly Le  19.0  Female
# 1958  a43e558c-2215-4f00-9fdf-0e05c0cef31b  Brenda Moreno MD  19.0  Female
# 1989  0b705933-4cde-4b6b-9132-567c51a40d2a    Ashley Sweeney  20.0  Female
# 1994  e0df9d28-94ae-404e-a5ca-3a2257b0e189             Sonal  23.0  Female
#
#      Branch  Average GPA  Backlogs  Attendance (%)  \
# ...

# %% [markdown]
# The **info()** method provides a concise summary of a DataFrame, including:
#
#     Index type and range: Information about the DataFrame's index.
#     Column names and their data types (dtypes): Identifies whether columns are numeric, object (strings), datetime, etc.
#     Non-null counts: Shows the number of non-missing values in each column, which helps in identifying missing data.
#     Memory usage: Estimates the memory consumed by the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Student ID         1999 non-null   object
#  1   Name               2000 non-null   object
#  2   Age                1999 non-null   float64
#  3   Gender             1999 non-null   object
#  4   Branch             1999 non-null   object
#  5   Average GPA        1999 non-null   float64
#  6   Backlogs           1999 non-null   float64
#  7   Attendance (%)     1999 non-null   float64
#  8   Clubs              1999 non-null   object
#  9   Skills             1999 non-null   object
#  10  Internship Done    1999 non-null   object
#  11  Internship Domain  982 non-null    object
#  12  Placement Status   1999 non-null   object
#  13  Placement Domain   1032 non-null   object
#  14  CTC (LPA)          1999 non-null   float64
#  15  Alumni Path        1032 non-null   object
# ...

# %% [markdown]
# The describe() method generates descriptive statistics of the DataFrame's columns. By default, it focuses on numerical columns, providing:
#
#     count: Number of non-null values.
#     mean: Average value.
#     std: Standard deviation.
#     min: Minimum value.
#     25% (Q1): 25th percentile (first quartile).
#     50% (Q2): 50th percentile (median).
#     75% (Q3): 75th percentile (third quartile).
#     max: Maximum value.

# %%
df.describe()
# Out:
#                Age  Average GPA     Backlogs  Attendance (%)    CTC (LPA)  \
# count  1999.000000  1999.000000  1999.000000     1999.000000  1999.000000
# mean     20.474237     7.002616     0.966983       78.933147     5.795898
# std       1.728062     0.341148     0.990905       11.730931     6.563695
# min      18.000000     6.050000     0.000000       60.040000     0.000000
# 25%      19.000000     6.770000     0.000000       69.000000     0.000000
# 50%      21.000000     7.000000     1.000000       78.310000     3.460000
# 75%      22.000000     7.215000     1.000000       89.220000    11.260000
# max      23.000000     8.070000     5.000000       99.980000    19.990000
#
#           Sem1 GPA    Sem2 GPA     Sem3 GPA     Sem4 GPA     Sem5 GPA  \
# count  1999.000000  1999.00000  1999.000000  1999.000000  1999.000000
# mean      6.976433     7.08021     6.980905     6.961736     7.037894
# std       0.966329     1.03160     0.985273     0.983697     0.984407
# ...

# %% [markdown]
# Column selection:
#
# we can find the overall columns

# %%
df.columns
# Out:
# Index(['Student ID', 'Name', 'Age', 'Gender', 'Branch', 'Average GPA',
#        'Backlogs', 'Attendance (%)', 'Clubs', 'Skills', 'Internship Done',
#        'Internship Domain', 'Placement Status', 'Placement Domain',
#        'CTC (LPA)', 'Alumni Path', 'Sem1 GPA', 'Sem2 GPA', 'Sem3 GPA',
#        'Sem4 GPA', 'Sem5 GPA', 'Sem6 GPA', 'Sem7 GPA', 'Sem8 GPA', 'Salary'],
#       dtype='object')

# %% [markdown]
# Select multiple columns by using the below syntax

# %%
df[['Student ID', 'Branch', 'Average GPA']]
# Out:
#                                 Student ID Branch  Average GPA
# 0     b37412a3-fa5c-40ca-b087-7109a47482d7   MECH         6.99
# 1     65001423-faeb-4d19-a550-8ea26133a34d    ECE         6.46
# 2     228aaf1d-8710-4c8d-bfec-001b0df01f34  CIVIL         7.08
# 3     1aa67474-e200-4157-ad54-c95aaa4d52a8    ECE         6.92
# 4     5122db4a-14c8-44d7-b2f4-e869f69d3dd7    EEE         7.09
# ...                                    ...    ...          ...
# 1995  27d7e5aa-dc11-40a7-9aff-586f00f8d55b     IT         7.69
# 1996  74f43a77-70a1-4e4c-a0c2-460d939618c9  CIVIL         7.25
# 1997  88a613b4-a3b8-4f92-a3c9-0c6a86017633    EEE         6.92
# 1998  248c7b65-0c61-4277-9e95-44857b54d1a9    CSE         7.09
# 1999  840d718e-de7b-4218-95bd-11db983c3cbd     IT         6.52
#
# [2000 rows x 3 columns]

# %% [markdown]
# Filter rows:

# %%
df.Age.sort_values(ascending=False)
# Out:
# 50      23.0
# 54      23.0
# 1981    23.0
# 1002    23.0
# 1005    23.0
#         ...
# 90      18.0
# 96      18.0
# 102     18.0
# 446     18.0
# 863      NaN
# Name: Age, Length: 2000, dtype: float64

# %%
df[df['Branch'] == 'MECH']
# Out:
#                                 Student ID            Name   Age  Gender  \
# 0     b37412a3-fa5c-40ca-b087-7109a47482d7            Amit  21.0    Male
# 5     28dd6ff3-6391-4421-ba38-3c3164b96252       Siddharth  19.0    Male
# 6     5c375254-a8fc-4690-a9b1-c4a1da221b85   Alicia Dillon  18.0  Female
# 17    7a8d03aa-782a-45e0-88ca-765192f5df7b   Cody Williams  21.0  Female
# 18    6d59c708-298e-45cc-a9e6-eaa3024e260c           Priya  22.0  Female
# ...                                    ...             ...   ...     ...
# 1973  c93c9cc6-668b-48da-8222-cd7f36e6ba85    Joshua Terry  21.0    Male
# 1974  3db60d0c-66d4-4e39-8c41-72446d04be48           Rakhi  18.0  Female
# 1979  b40a3f7d-353d-45f8-b1f0-69a983a0ba0f            Amit  22.0    Male
# 1989  0b705933-4cde-4b6b-9132-567c51a40d2a  Ashley Sweeney  20.0  Female
# 1994  e0df9d28-94ae-404e-a5ca-3a2257b0e189           Sonal  23.0  Female
#
#      Branch  Average GPA  Backlogs  Attendance (%)  \
# ...

# %% [markdown]
# ## 🛠️ 4. Data Cleaning & Preprocessing

# %% [markdown]
# Handling nulls:
# Find null values in each colum

# %%
df.isnull().sum()
# Out:
# Student ID              1
# Name                    0
# Age                     1
# Gender                  1
# Branch                  1
# Average GPA             1
# Backlogs                1
# Attendance (%)          1
# Clubs                   1
# Skills                  1
# Internship Done         1
# Internship Domain    1018
# Placement Status        1
# Placement Domain      968
# CTC (LPA)               1
# Alumni Path           968
# Sem1 GPA                1
# Sem2 GPA                1
# Sem3 GPA                1
# Sem4 GPA                1
# Sem5 GPA                1
# Sem6 GPA                1
# Sem7 GPA                1
# Sem8 GPA                1
# Salary                  1
# dtype: int64

# %% [markdown]
# drop null values using **dropna()** of entire dataset

# %%
drop_df=df.copy()

# %%
drop_df.dropna(inplace=True)

# %%
drop_df.shape
# Out:
# (481, 25)

# %% [markdown]
# drop null values using dropna() on particular field

# %%
drop_df2=df.copy()

# %%
drop_df2.dropna(subset=['Placement Domain'], inplace=True)

# %%
drop_df2.shape
# Out:
# (1032, 25)

# %% [markdown]
# ## Type conversions:

# %%
df.Age.dtype
# Out:
# dtype('float64')

# %%
df_age=df.copy()
df_age['Age']=df_age['Age'].fillna(df_age['Age'].mean())   #before converting int/float we need to remove the nan values

# %%
df_age['Age'] = df_age['Age'].astype(int)

# %%
df_age.Age.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Renaming columns:

# %%
df.rename(columns={'CTC (LPA)': 'Salary'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Student ID', 'Name', 'Age', 'Gender', 'Branch', 'Average GPA',
#        'Backlogs', 'Attendance (%)', 'Clubs', 'Skills', 'Internship Done',
#        'Internship Domain', 'Placement Status', 'Placement Domain', 'Salary',
#        'Alumni Path', 'Sem1 GPA', 'Sem2 GPA', 'Sem3 GPA', 'Sem4 GPA',
#        'Sem5 GPA', 'Sem6 GPA', 'Sem7 GPA', 'Sem8 GPA', 'Salary'],
#       dtype='object')

# %% [markdown]
# ## 🔄 5. Feature Engineering
# ## http://localhost:8888/notebooks/Desktop/Medium_Documents/Pandas_Lambda.ipynb
#
# Create new column—e.g. salary category:

# %%
df.columns
# Out:
# Index(['Student ID', 'Name', 'Age', 'Gender', 'Branch', 'Average GPA',
#        'Backlogs', 'Attendance (%)', 'Clubs', 'Skills', 'Internship Done',
#        'Internship Domain', 'Placement Status', 'Placement Domain', 'Salary',
#        'Alumni Path', 'Sem1 GPA', 'Sem2 GPA', 'Sem3 GPA', 'Sem4 GPA',
#        'Sem5 GPA', 'Sem6 GPA', 'Sem7 GPA', 'Sem8 GPA', 'Salary'],
#       dtype='object')

# %%
df.Salary.mean()
# Out:
# Salary         5.795898
# Salary    579589.794897
# dtype: float64

# %%
df['Salary_level'] = df['Salary'].apply(lambda x: 'High' if x > df['Salary'].mean() else 'Low')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df['Salary_level'] = df['Salary'].apply(lambda x: 'High' if x > df['Salary'].mean() else 'Low')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:965, in FrameApply.apply_standard(self)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Student ID         1999 non-null   object
#  1   Name               2000 non-null   object
#  2   Age                1999 non-null   float64
#  3   Gender             1999 non-null   object
#  4   Branch             1999 non-null   object
#  5   Average GPA        1999 non-null   float64
#  6   Backlogs           1999 non-null   float64
#  7   Attendance (%)     1999 non-null   float64
#  8   Clubs              1999 non-null   object
#  9   Skills             1999 non-null   object
#  10  Internship Done    1999 non-null   object
#  11  Internship Domain  982 non-null    object
#  12  Placement Status   1999 non-null   object
#  13  Placement Domain   1032 non-null   object
#  14  Salary             1999 non-null   float64
#  15  Alumni Path        1032 non-null   object
# ...

# %%
df.Salary_level.value_counts()

# %% [markdown]
# ## 🧮 6. GroupBy & Aggregation  http://localhost:8888/notebooks/Desktop/Medium_Documents/Pandas_Groupby.ipynb

# %% [markdown]
# Mean CGPA per branch:

# %%
df.columns
# Out:
# Index(['Student ID', 'Name', 'Age', 'Gender', 'Branch', 'Average GPA',
#        'Backlogs', 'Attendance (%)', 'Clubs', 'Skills', 'Internship Done',
#        'Internship Domain', 'Placement Status', 'Placement Domain', 'Salary',
#        'Alumni Path', 'Sem1 GPA', 'Sem2 GPA', 'Sem3 GPA', 'Sem4 GPA',
#        'Sem5 GPA', 'Sem6 GPA', 'Sem7 GPA', 'Sem8 GPA', 'Salary'],
#       dtype='object')

# %%
df.groupby('Branch')['Sem1 GPA'].mean().sort_values(ascending=False)
# Out:
# Branch
# CIVIL    7.052557
# IT       7.016462
# MECH     7.006034
# ECE      6.994458
# EEE      6.947864
# CSE      6.815034
# Name: Sem1 GPA, dtype: float64

# %%
df.columns
# Out:
# Index(['Student ID', 'Name', 'Age', 'Gender', 'Branch', 'Average GPA',
#        'Backlogs', 'Attendance (%)', 'Clubs', 'Skills', 'Internship Done',
#        'Internship Domain', 'Placement Status', 'Placement Domain', 'Salary',
#        'Alumni Path', 'Sem1 GPA', 'Sem2 GPA', 'Sem3 GPA', 'Sem4 GPA',
#        'Sem5 GPA', 'Sem6 GPA', 'Sem7 GPA', 'Sem8 GPA', 'Salary'],
#       dtype='object')

# %% [markdown]
# Custom aggregation:

# %%
df.groupby('Gender').agg({'Sem1 GPA': ['mean', 'max'], 'Salary': 'median'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_294310/4133111365.py in ?()
# ----> 1 df.groupby('Gender').agg({'Sem1 GPA': ['mean', 'max'], 'Salary': 'median'})
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py in ?(self, func, engine, engine_kwargs, *args, **kwargs)
#    1441             kwargs["engine"] = engine
#    1442             kwargs["engine_kwargs"] = engine_kwargs
#    1443
#    1444         op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1445         result = op.agg()
#    1446         if not is_dict_like(func) and result is not None:
#    1447             # GH #52849
#    1448             if not self.as_index and is_list_like(func):
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py in ?(self)
#     171         if isinstance(func, str):
#     172             return self.apply_str()
#     173
# ...

# %% [markdown]
# ## 🧠 7. Pivot Table & Crosstab
# ## http://localhost:8888/notebooks/Desktop/Medium_Documents/Pandas_Pivot_table.ipynb
# Pivot example:

# %%
pd.pivot_table(df, index='Branch', columns='Salary_level', values='Sem1 GPA', aggfunc='mean')

# %% [markdown]
# Crosstab example:

# %%
pd.crosstab(df['Placement Status'], df['Salary_level'])

# %% [markdown]
# ## 🔁 8. Handling Time/Ordering (if present)
#
# ## http://localhost:8888/notebooks/Desktop/Medium_Documents/Pandas_Time_Series.ipynb
#     If dataset has dates, show datetime conversion:

# %%
df['placed_date']=pd.date_range(start='2023-01-01', periods=len(df), freq='W')  #create dummy date

# %%
df['Placement Status'].value_counts()

# %%
filt_df=df[df['Placement Status']=="Not Placed"]
filt_df['placed_date']=pd.NaT

# %%
df=df[df['Placement Status']=="Placed"]
df=pd.concat([df,filt_df],ignore_index=False)

# %%
df['Placement Status'].value_counts()

# %%
df.placed_date.value_counts()

# %%
df

# %%
df['placed_date'] = pd.to_datetime(df['placed_date'])
df.set_index('placed_date', inplace=True)
df.resample('M')['Salary'].mean()

# %% [markdown]
# ## 🎯 9. Mini Analysis
#     Top 5 branches by mean salary
#
#     Relationship between CGPA and salary (scatter + correlation)
#
#     Salary comparison by gender or other features

# %%
df.columns

# %%
df.groupby('Branch')['Salary'].mean().sort_values(ascending=False).head()

# %% [markdown]
# ## Relationship Between CGPA and Salary

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=df, x='Sem1 GPA', y='Salary')
plt.title('CGPA vs Salary')
plt.xlabel('CGPA')
plt.ylabel('Salary')
plt.show()

# %%
# Correlation
correlation = df[['Sem1 GPA', 'Salary']].corr()
correlation

# %% [markdown]
# ## Salary Comparison by Gender

# %%
sns.boxplot(data=df, x='Gender', y='Salary')
plt.title('Salary Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.show()
